# %% [markdown]
# # <center> Analyzing Stock Prices

# %% [markdown]
# This is project will process with stock market data download from [Yahoo Finance](https://finance.yahoo.com/?guccounter=1&guce_referrer=aHR0cHM6Ly9hcHAuZGF0YXF1ZXN0LmlvLw&guce_referrer_sig=AQAAAKPs15pddqDC0ArpmhoVIgtjznOl8Yg8LMAQPNy4zGRr_lJvpk1A_6yIgVm7V_9AOR5R2I8S3cS7dveRAQMr1Ps-Ntf1TXHjjm5x0pA_cpeGIuM0dx9qDN54RpHQvVjy_3V8QdnIGg2lGRyu2J2EL8sJ7mm3giAwCccQOBvOP1cF) using the [yahoo_finance](https://pypi.org/project/yahoo-finance/) Python package. This data consists of the daily stock prices from 2007-1-1 to 2017-04-17 for several hundred symbols traded on the NASDAQ stock exchange, stored in the prices folder. Each file in the prices folder has a specific stock symbol for its name, and each contains the following information:
#
# - date : the data's date
# - close : the date's closing price
# - open : the date's opening price
# - high : the date's highest stock price during trading
# - low : the date's lowest stock price during trading
# - volumne : the date's number of shares traded

# %% [markdown]
# ## Read all files in folder

# %%
import pandas as pd 
import os 

stock_prices = {} 
for fn in os.listdir("prices") : 
    df = pd.read_csv(os.path.join("prices", fn))
    stock = fn.split('.')[0]
    stock_prices[stock] = df

# %%
# Display the data corresponding to the aapl symbol
stock_prices['aapl'].head()
# Out:
#          date      close       open       high        low     volume
# 0  2007-01-03  83.800002  86.289999  86.579999  81.899999  309579900
# 1  2007-01-04  85.659998  84.050001  85.949998  83.820003  211815100
# 2  2007-01-05  85.049997  85.770000  86.199997  84.400002  208685400
# 3  2007-01-08  85.470000  85.959998  86.529998  85.280003  199276700
# 4  2007-01-09  92.570003  86.450003  92.979999  85.150000  837324600

# %% [markdown]
# ## Calculate aggregates
#
# After reading all file in folder and storing them into dictionary, we can use it to compute aggregate.
#
# - The average closing price of each stock
# - The minimum average closing price over all stocks
# - The maximum average closing price over all stocks

# %%
# Calculate the stock symbol with the closing average price

average_closing_prices = {}
for stock in stock_prices : 
    average_closing_prices[stock] = stock_prices[stock]['close'].mean()
    print(f"Stock name : {stock}, Price : {average_closing_prices[stock]}")
# Out:
# Stock name : dgica, Price : 14.986583006177607
# Stock name : bdge, Price : 24.12035132432432
# Stock name : cvco, Price : 53.36543631042471
# Stock name : blkb, Price : 33.75537838185328
# Stock name : bbox, Price : 25.997579137451737
# Stock name : ffbc, Price : 16.002316604633204
# Stock name : fbiz, Price : 22.958876448262547
# Stock name : ffic, Price : 16.59364864787645
# Stock name : bdsi, Price : 4.8207065644787646
# Stock name : amgn, Price : 92.2331003965251
# Stock name : expe, Price : 53.78315830308881
# Stock name : expd, Price : 42.86821235366795
# Stock name : cur, Price : 1.907691699604743
# Stock name : clct, Price : 14.4366796011583
# Stock name : alny, Price : 39.171486488030894
# Stock name : evol, Price : 5.701853281853282
# Stock name : ahgp, Price : 38.20530885868726
# Stock name : dfbg, Price : 1.4005010393822395
# Stock name : afsi, Price : 26.69982658918919
# Stock name : chy, Price : 12.45603860888031
# Stock name : bmrn, Price : 50.52171040733592
# Stock name : agys, Price : 10.303613901544402
# Stock name : adrd, Price : 22.51748262046332
# Stock name : drrx, Price : 2.352779922779923
# Stock name : crus, Price : 20.50549421969112
# Stock name : brew, Price : 8.094903474517373
# Stock name : fbms, Price : 14.224830092664092
# Stock name : emcf, Price : 22.219915054826256
# Stock name : bsqr, Price : 4.305370656370656
# Stock name : csfl, Price : 11.947644780694981
# Stock name : car, Price : 24.829617774131272
# Stock name : cmcsa, Price : 35.904505792277995
# Stock name : capr, Price : 2.473247462919594
# Stock name : cmtl, Price : 30.96300771621621
# Stock name : elos, Price : 11.39328957027027
# Stock name : cplp, Price : 9.927482215019763
# Stock name : eltk, Price : 1.5323436293436294
# Stock name : agii, Price : 40.817575337065634
# Stock name : coke, Price : 80.56527417181468
# Stock name : egan, Price : 3.5465791505791504
# Stock name : cpss, Price : 3.9003629343629345
# Stock name : adtn, Price : 23.847494206177608
# Stock name : ffiv, Price : 86.29457917374518
# Stock name : cspi, Price : 6.0528571428571425
# Stock name : bwen, Price : 5.326498072200772
# Stock name : cgnx, Price : 32.55762165714286
# Stock name : cdns, Price : 14.24691891119691
# Stock name : egt, Price : 1.3293513513513513
# Stock name : cray, Price : 15.423347486486486
# Stock name : arcw, Price : 5.706739867181468
# Stock name : bncn, Price : 13.986131252895754
# Stock name : admp, Price : 1.7122164397683397
# Stock name : cnsl, Price : 18.772135127027028
# Stock name : abax, Price : 34.57868337992278
# Stock name : aris, Price : 2.1661389961389963
# Stock name : cyrn, Price : 2.7131410714285717
# Stock name : asys, Price : 8.914054046332048
# Stock name : bosc, Price : 2.1880193050193046
# Stock name : achn, Price : 5.941177606949807
# Stock name : ahpi, Price : 3.404389961389961
# Stock name : ebay, Price : 35.18885618648648
# Stock name : apog, Price : 26.00773359150579
# Stock name : camp, Price : 9.500046333590733
# Stock name : acor, Price : 27.47286873938224
# Stock name : ewbc, Price : 26.819362960231665
# Stock name : artw, Price : 7.46590346911197
# Stock name : cvgi, Price : 8.536474901930502
# Stock name : czwi, Price : 7.406482625482626
# Stock name : cprt, Price : 37.017694950579155
# Stock name : cfnb, Price : 13.825111963706565
# Stock name : astc, Price : 1.4152123552123552
# Stock name : csii, Price : 13.978281854440155
# Stock name : daio, Price : 3.651555984555984
# Stock name : amri, Price : 11.358054055598457
# Stock name : ctib, Price : 4.690494208494208
# Stock name : flws, Price : 5.78195752895753
# Stock name : ccbg, Price : 16.26640926872587
# Stock name : cizn, Price : 20.431698791505795
# Stock name : dwaq, Price : 55.77838609343629
# Stock name : flxs, Price : 22.836366786486487
# Stock name : cnob, Price : 13.295115791505792
# Stock name : clsn, Price : 3.00828185019305
# Stock name : arql, Price : 3.8744247104247105
# Stock name : attu, Price : 4.317359073359073
# Stock name : cybe, Price : 9.964861003861003
# Stock name : cpsh, Price : 1.9615839865149598
# Stock name : fmbi, Price : 17.350911196138995
# Stock name : awre, Price : 4.083567567567567
# Stock name : adsk, Price : 42.24759463281853
# Stock name : ccmp, Price : 39.67996139150579
# Stock name : dgii, Price : 10.495293435521234
# Stock name : acad, Price : 13.823586874903475
# Stock name : arow, Price : 25.715315076833974
# Stock name : ea, Price : 37.33655212046332
# Stock name : atvi, Price : 19.92204634131274
# Stock name : cass, Price : 42.141633734749036
# Stock name : ecpg, Price : 24.97440927104247
# Stock name : cmct, Price : 11.270061818532819
# Stock name : cytx, Price : 3.3293219922779924
# Stock name : cznc, Price : 18.655586874131274
# Stock name : atec, Price : 2.7025780428571426
# Stock name : bont, Price : 10.085776056370657
# Stock name : cdti, Price : 4.001780249420849
# Stock name : crds, Price : 1.8903166015444013
# Stock name : adru, Price : 22.37166796177606
# Stock name : fizz, Price : 19.844949835907332
# Stock name : aey, Price : 2.6871505791505794
# Stock name : ctrn, Price : 20.54685713976834
# Stock name : dnbf, Price : 16.71552883088803
# Stock name : chmg, Price : 26.421312745173747
# Stock name : call, Price : 10.101200768339767
# Stock name : boch, Price : 6.063119691119691
# Stock name : ancx, Price : 12.260374515444015
# Stock name : cfcb, Price : 7.65700699961375
# Stock name : acgl, Price : 63.32590737683399
# Stock name : atro, Price : 31.862567476833977
# Stock name : ffin, Price : 42.17889953474903
# Stock name : ango, Price : 14.802289587258688
# Stock name : dwsn, Price : 6.194910959459459
# Stock name : eght, Price : 5.531308880694981
# Stock name : ctrp, Price : 45.163220061389964
# Stock name : dakt, Price : 12.215868713513514
# Stock name : depo, Price : 8.988274123938224
# Stock name : ctsh, Price : 57.91491119652509
# Stock name : cpsi, Price : 44.443451738996146
# Stock name : cnxn, Price : 14.347270266795366
# Stock name : bldp, Price : 2.3273861003861
# Stock name : belfb, Price : 21.680702705791507
# Stock name : esca, Price : 8.187945943243243
# Stock name : botj, Price : 9.858123591891891
# Stock name : bwld, Price : 89.39383399150579
# Stock name : dgas, Price : 24.959196903088806
# Stock name : bobe, Price : 37.68301545907335
# Stock name : brks, Price : 10.524733592277991
# Stock name : ccne, Price : 15.950173729729729
# Stock name : cytr, Price : 1.9986748837837838
# Stock name : cy, Price : 14.158153035907336
# Stock name : cown, Price : 5.948822393822394
# Stock name : cern, Price : 65.04237453166023
# Stock name : eqfn, Price : 5.558436266023166
# Stock name : aemd, Price : 1.3980424710424713
# Stock name : fele, Price : 38.77260231583011
# Stock name : cpst, Price : 1.206953667953668
# Stock name : expo, Price : 46.09936678262548
# Stock name : axas, Price : 2.8366293436293435
# Stock name : crtn, Price : 2.1850579150579152
# Stock name : efii, Price : 25.840223945945947
# Stock name : alco, Price : 34.68778766100386
# Stock name : cutr, Price : 11.777822398841698
# Stock name : amkr, Price : 6.955822393436294
# Stock name : cenx, Price : 18.39556755173745
# Stock name : bcrx, Price : 6.095837838223938
# Stock name : ctxs, Price : 58.02012394942085
# Stock name : caas, Price : 7.633440158301158
# Stock name : cers, Price : 4.2464787644787645
# Stock name : cake, Price : 34.3126757027027
# Stock name : amrn, Price : 3.9924594610038606
# Stock name : bwinb, Price : 23.673023192664093
# Stock name : asrv, Price : 2.8011698841698838
# Stock name : atri, Price : 228.38977615984555
# Stock name : adra, Price : 27.35145173976834
# Stock name : emms, Price : 2.2464208494208497
# Stock name : avdl, Price : 10.10303474015444
# Stock name : falc, Price : 3.6092123552123554
# Stock name : bpopn, Price : 21.34707336023166
# Stock name : fisi, Price : 19.93808495096525
# Stock name : bwina, Price : 23.12426251196911
# Stock name : fll, Price : 2.4715752895752896
# Stock name : apri, Price : 1.8681738996139
# Stock name : dlhc, Price : 1.8903745173745172
# Stock name : boom, Price : 20.597038611196908
# Stock name : esnd, Price : 40.798293426640925
# Stock name : diod, Price : 22.849976832046334
# Stock name : cvv, Price : 8.6243861019305
# Stock name : dsgx, Price : 9.768467180694982
# Stock name : arkr, Price : 20.460409264092664
# Stock name : cohu, Price : 12.740305017374517
# Stock name : cgnt, Price : 1.5946138996138997
# Stock name : casy, Price : 58.49573744092663
# Stock name : ceva, Price : 17.12422007104247
# Stock name : camt, Price : 2.402606177606178
# Stock name : bjri, Price : 31.854320508108106
# Stock name : dish, Price : 39.2437143050193
# Stock name : buse, Price : 10.920324543629343
# Stock name : dltr, Price : 57.418077247490345
# Stock name : cvcy, Price : 9.671478766409265
# Stock name : exas, Price : 9.390011581081081
# Stock name : abcb, Price : 17.990475994208495
# Stock name : crmt, Price : 30.5432779945946
# Stock name : algt, Price : 83.70168345444017
# Stock name : flex, Price : 8.817428571814672
# Stock name : fast, Price : 44.40756368957529
# Stock name : cyan, Price : 4.164428571428572
# Stock name : epay, Price : 20.79650191235521
# Stock name : amwd, Price : 34.320258717374514
# Stock name : cvti, Price : 10.437138995752894
# Stock name : alxn, Price : 97.1099267011583
# Stock name : calm, Price : 38.32738610810811
# Stock name : cnit, Price : 3.604745173745174
# Stock name : afam, Price : 29.43431277065637
# Stock name : educ, Price : 5.948108107722009
# Stock name : dysl, Price : 1.863166023166023
# Stock name : csgs, Price : 23.515061787258688
# Stock name : ccoi, Price : 23.23651737760618
# Stock name : cpla, Price : 54.80040545714285
# Stock name : dmrc, Price : 22.263640273510973
# Stock name : cntf, Price : 2.659563711969112
# Stock name : evep, Price : 31.358648642471042
# Stock name : cuba, Price : 7.751552123552123
# Stock name : cthr, Price : 2.4644787644787645
# Stock name : cwco, Price : 13.6181776
# Stock name : anip, Price : 17.234360110038608
# Stock name : actg, Price : 15.997490346718147
# Stock name : cpah, Price : 1.4116189448441248
# Stock name : ctic, Price : 1.494366311969112
# Stock name : bgcp, Price : 7.162189189189189
# Stock name : efsc, Price : 18.541934354826257
# Stock name : cacc, Price : 95.49895756602318
# Stock name : bofi, Price : 31.21098066177607
# Stock name : chfn, Price : 15.708602240154441
# Stock name : cban, Price : 8.232640922779924
# Stock name : colm, Price : 53.72719691235521
# Stock name : celg, Price : 85.09483015984556
# Stock name : amzn, Price : 275.13407757104255
# Stock name : entg, Price : 9.497733591505792
# Stock name : ffhl, Price : 2.1926872586872586
# Stock name : acet, Price : 12.655212363320464
# Stock name : aegn, Price : 19.89972970926641
# Stock name : dvcr, Price : 7.688459461389963
# Stock name : bcor, Price : 13.260498064864864
# Stock name : arrs, Price : 17.104613885328185
# Stock name : dhil, Price : 104.54806553783784
# Stock name : crws, Price : 5.629305019305019
# Stock name : cemi, Price : 2.482177606177606
# Stock name : cui, Price : 3.2413753598455597
# Stock name : aplp, Price : 23.031826284169885
# Stock name : cunb, Price : 15.998223935135135
# Stock name : chnr, Price : 8.12607720965251
# Stock name : egbn, Price : 23.78503891003861
# Stock name : casc, Price : 3.0625407166023164
# Stock name : ctbi, Price : 32.61787694054054
# Stock name : avir, Price : 3.4036661768339767
# Stock name : fdef, Price : 23.233142840926643
# Stock name : asrvp, Price : 25.09542473243243
# Stock name : clmt, Price : 23.327073368339768
# Stock name : atni, Price : 47.67885716216217
# Stock name : bios, Price : 5.790710422779922
# Stock name : denn, Price : 5.761945945945946
# Stock name : cvly, Price : 15.412107433976836
# Stock name : discb, Price : 39.652757378378375
# Stock name : cinf, Price : 42.25041697451738
# Stock name : fcnca, Price : 200.2524827814672
# Stock name : dtrm, Price : 3.723555984555984
# Stock name : ebix, Price : 32.532169762934366
# Stock name : acls, Price : 3.343806946718147
# Stock name : bokf, Price : 56.16893048532818
# Stock name : bde, Price : 7.226011583011584
# Stock name : bbby, Price : 50.183324364864866
# Stock name : casm, Price : 2.4918
# Stock name : cbli, Price : 3.610266410424711
# Stock name : fhco, Price : 4.288459459459459
# Stock name : banfp, Price : 26.41583782548263
# Stock name : dzsi, Price : 1.5382316602316604
# Stock name : belfa, Price : 21.04013901081081
# Stock name : czfc, Price : 9.846169883783784
# Stock name : caty, Price : 21.829671827027028
# Stock name : cyccp, Price : 4.965254826254826
# Stock name : aezs, Price : 1.7391445949806952
# Stock name : akam, Price : 42.81851348687258
# Stock name : elon, Price : 6.949154477992277
# Stock name : csgp, Price : 103.10355984362937
# Stock name : ebtc, Price : 17.201536692277994
# Stock name : clbs, Price : 2.2820694980694984
# Stock name : cnty, Price : 4.444320463320464
# Stock name : aimc, Price : 20.99966024942085
# Stock name : dxpe, Price : 38.61513902084942
# Stock name : eqix, Price : 165.3847721150579
# Stock name : amot, Price : 9.96724324015444
# Stock name : cris, Price : 2.4645714285714284
# Stock name : aal, Price : 22.07495366679537
# Stock name : aeis, Price : 20.003212338996136
# Stock name : dox, Price : 37.75929727606178
# Stock name : csbr, Price : 1.2282443845854416
# Stock name : cresy, Price : 13.09593044787645
# Stock name : bcli, Price : 0.9969415324324326
# Stock name : cvbf, Price : 12.391718153667954
# Stock name : aciw, Price : 28.27269496023166
# Stock name : arlp, Price : 46.942791493436296
# Stock name : asur, Price : 3.873123663706563
# Stock name : cbak, Price : 2.4378957528957526
# Stock name : ca, Price : 25.74628186023166
# Stock name : csiq, Price : 16.0704556007722
# Stock name : esbk, Price : 19.142613947490347
# Stock name : edap, Price : 3.2358030888030886
# Stock name : amtd, Price : 23.490517397683398
# Stock name : cart, Price : 6.340498070270271
# Stock name : civb, Price : 9.309308876833976
# Stock name : acta, Price : 11.320559837065638
# Stock name : ecol, Price : 28.210664105405407
# Stock name : aehr, Price : 2.6085559845559847
# Stock name : artx, Price : 2.0992316602316605
# Stock name : cme, Price : 230.2946601100386
# Stock name : cffn, Price : 21.4160772
# Stock name : csco, Price : 23.6288224027027
# Stock name : chrw, Price : 61.98583785675676
# Stock name : apwc, Price : 3.2336409266409265
# Stock name : arwr, Price : 4.130016216216216
# Stock name : cmco, Price : 20.1090116
# Stock name : bnso, Price : 1.7172548262548262
# Stock name : club, Price : 7.270509651737452
# Stock name : bmra, Price : 0.901011583011583
# Stock name : eslt, Price : 58.57627412471042
# Stock name : eei, Price : 12.263416957915059
# Stock name : amed, Price : 31.845227816216216
# Stock name : abtl, Price : 6.233108108494208
# Stock name : clro, Price : 6.852370656370656
# Stock name : ffkt, Price : 19.47292279305019
# Stock name : cffi, Price : 32.433154460617764
# Stock name : essa, Price : 12.126070440047489
# Stock name : amat, Price : 17.116648652509653
# Stock name : azpn, Price : 24.926833974517375
# Stock name : arii, Price : 31.49141313359073
# Stock name : alqa, Price : 1.405298283011583
# Stock name : aubn, Price : 23.59867953397683
# Stock name : exac, Price : 19.53100774169884
# Stock name : bcpc, Price : 41.03619678301158
# Stock name : adre, Price : 39.14505407104247
# Stock name : arcb, Price : 26.582247134362934
# Stock name : bybk, Price : 6.642911204633204
# Stock name : drys, Price : 13.49853955019305
# Stock name : esxb, Price : 4.032393822393822
# Stock name : achc, Price : 24.04779533822394
# Stock name : edgw, Price : 5.274084942084942
# Stock name : aaon, Price : 23.617386061776063
# Stock name : fbss, Price : 15.228308892277994
# Stock name : abeo, Price : 2.5932200772200775
# Stock name : cash, Price : 32.26195366332046
# Stock name : aapl, Price : 257.1765404023166
# Stock name : airt, Price : 12.430108102316604
# Stock name : aaww, Price : 44.33160229034749
# Stock name : else, Price : 4.060752895752896
# Stock name : bgfv, Price : 13.156471046718146
# Stock name : dxyn, Price : 6.331316601930502
# Stock name : cmpr, Price : 51.058057920077225
# Stock name : cgo, Price : 13.7736332
# Stock name : cbrl, Price : 76.63736287992279
# Stock name : arcc, Price : 14.933262535135134
# Stock name : cfbk, Price : 2.174841698841699
# Stock name : bcbp, Price : 11.546521235135135
# Stock name : exfo, Price : 4.995563706563707
# Stock name : brkl, Price : 10.241702702702703
# Stock name : fccy, Price : 10.679512464864866
# Stock name : core, Price : 44.28576448223938
# Stock name : exel, Price : 6.616277998455599
# Stock name : allt, Price : 9.180019302702703
# Stock name : algn, Price : 36.751629348648656
# Stock name : exls, Price : 26.46239382084942
# Stock name : dorm, Price : 34.767818543243244
# Stock name : chfc, Price : 27.265100385714288
# Stock name : audc, Price : 4.375227799227799
# Stock name : dcth, Price : 2.8911660231660226
# Stock name : elgx, Price : 8.976440163706563
# Stock name : ainv, Price : 9.949749044015444
# Stock name : bkmu, Price : 7.306324324324323
# Stock name : artna, Price : 20.97944401119691
# Stock name : asfi, Price : 11.159220083783783
# Stock name : ceco, Price : 13.657787633204634
# Stock name : ctws, Price : 30.461830105405404
# Stock name : cvlt, Price : 39.000996127413124
# Stock name : baby, Price : 21.25315058880309
# Stock name : atrc, Price : 11.84171041969112
# Stock name : cetv, Price : 24.057965252509653
# Stock name : banf, Price : 49.64349804169885
# Stock name : esgr, Price : 114.26885330617759
# Stock name : brcd, Price : 7.668254826254827
# Stock name : bidu, Price : 193.53191124478766
# Stock name : chscp, Price : 29.073046355984555
# Stock name : cvgw, Price : 29.56466022934363
# Stock name : asml, Price : 59.040315206563704
# Stock name : bvsn, Price : 8.850015447876448
# Stock name : byfc, Price : 3.4977644787644784
# Stock name : cent, Price : 11.431996134749035
# Stock name : cbio, Price : 8.433602686100386
# Stock name : egle, Price : 8.04607291274131
# Stock name : biol, Price : 2.638343634749034
# Stock name : atax, Price : 5.999752895752896
# Stock name : acxm, Price : 18.263061783783783
# Stock name : cyrx, Price : 1.1615408884169884
# Stock name : chci, Price : 1.4581224154440156
# Stock name : adxs, Price : 3.166938612355212
# Stock name : aste, Price : 37.29283010849421
# Stock name : etfc, Price : 14.956660266795364
# Stock name : cbmx, Price : 3.7302140003860997
# Stock name : cnbka, Price : 30.143177581081087
# Stock name : csbk, Price : 11.70866774131274
# Stock name : bfin, Price : 10.907671818146719
# Stock name : avhi, Price : 22.406231679150576
# Stock name : chke, Price : 19.15281466100386
# Stock name : dvax, Price : 6.033752898455599
# Stock name : cool, Price : 1.5475988922779922
# Stock name : bmrc, Price : 39.35481079459459
# Stock name : basi, Price : 2.4194633204633202
# Stock name : alog, Price : 64.74335521467181
# Stock name : cidm, Price : 1.9935057915057917
# Stock name : dswl, Price : 3.529177606177606
# Stock name : cprx, Price : 1.9762007722007724
# Stock name : amsc, Price : 13.049243415057914
# Stock name : endp, Price : 37.34726641737452
# Stock name : alot, Price : 10.286698842084943
# Stock name : bksc, Price : 13.71162152857143
# Stock name : cbfv, Price : 18.72878765019305
# Stock name : crox, Price : 16.676393825482627
# Stock name : cwst, Price : 6.658471042471043
# Stock name : asna, Price : 17.81176063204633
# Stock name : abco, Price : 47.64705796756756
# Stock name : axgn, Price : 3.82023166023166
# Stock name : eeft, Price : 35.11525484749034
# Stock name : cece, Price : 9.062675674517374
# Stock name : apdn, Price : 0.8241009938223938
# Stock name : fbnc, Price : 16.11827027027027
# Stock name : cbsh, Price : 42.69090342934363
# Stock name : dcom, Price : 14.727355209652508
# Stock name : dave, Price : 12.284664105405405
# Stock name : csq, Price : 10.269231660231661
# Stock name : biib, Price : 164.53822006138998
# Stock name : extr, Price : 3.537501930501931
# Stock name : bebe, Price : 6.41819694980695
# Stock name : amsf, Price : 30.34488032162162
# Stock name : akrx, Price : 15.387104233590733
# Stock name : cytk, Price : 4.7425641938223935
# Stock name : dgicb, Price : 18.359567528185327
# Stock name : adbe, Price : 51.199436284169884
# Stock name : anik, Price : 20.77447492046332
# Stock name : alsk, Price : 5.995567569498069
# Stock name : finl, Price : 17.24175289150579
# Stock name : ardm, Price : 1.928069498069498
# Stock name : farm, Price : 20.193166013513515
# Stock name : disca, Price : 39.234679803474904
# Stock name : dest, Price : 18.788065616216212
# Stock name : bmtc, Price : 23.783575303088803
# Stock name : ccrn, Price : 10.054741314671816
# Stock name : eric, Price : 13.297131263706566
# Stock name : conn, Price : 21.148482605791504
# Stock name : ezpw, Price : 15.789984552895751
# Stock name : bpop, Price : 17.295227834362933
# Stock name : crme, Price : 5.622293436293436
# Stock name : clrb, Price : 1.2045711436293434
# Stock name : cycc, Price : 2.667563561003861
# Stock name : cort, Price : 3.2995482625482624
# Stock name : fisv, Price : 67.52742853513513
# Stock name : blfs, Price : 0.8122763011583011
# Stock name : cfnl, Price : 14.268891889189188
# Stock name : chkp, Price : 51.12600387451738
# Stock name : faro, Price : 34.87222776949807
# Stock name : aame, Price : 2.779679536679537
# Stock name : bbry, Price : 43.67659082355212
# Stock name : eml, Price : 17.330768325482623
# Stock name : evlv, Price : 3.972590733590733
# Stock name : amag, Price : 32.49387646872587
# Stock name : apps, Price : 1.8256061776061776
# Stock name : amnb, Price : 22.11375289034749
# Stock name : emitf, Price : 12.964027813127412
# Stock name : atlo, Price : 22.101030884555986
# Stock name : emkr, Price : 4.458320463320463
# Stock name : cldx, Price : 9.006351276061778
# Stock name : crnt, Price : 6.269598454826255
# Stock name : dxtr, Price : 2.7493397683397682
# Stock name : cgen, Price : 4.882621621621621
# Stock name : avav, Price : 26.558296459060923
# Stock name : dxcm, Price : 28.520806964092667
# Stock name : arry, Price : 5.182899613899614
# Stock name : axdx, Price : 8.656428568339768
# Stock name : cdor, Price : 2.6057721938223937
# Stock name : chdn, Price : 72.21778764864865
# Stock name : aaxn, Price : 11.863907341698841
# Stock name : amswa, Price : 8.076181467181467
# Stock name : cigi, Price : 32.206258406177604
# Stock name : clfd, Price : 8.055154443629345
# Stock name : arlz, Price : 7.441718146718148
# Stock name : bset, Price : 13.877702711583012
# Stock name : chi, Price : 12.602803088416989
# Stock name : cohr, Price : 53.712150582625476
# Stock name : cree, Price : 36.52946716216216
# Stock name : ehth, Price : 18.97314286911197
# Stock name : ccur, Price : 4.987629343629343
# Stock name : acfc, Price : 5.596733538610039
# Stock name : djco, Price : 110.25166789845558
# Stock name : bbgi, Price : 5.338297297297297
# Stock name : cald, Price : 8.60896525096525
# Stock name : emci, Price : 25.21568724942085
# Stock name : cacb, Price : 7.012756795366795
# Stock name : adi, Price : 42.24018144826255
# Stock name : crai, Price : 27.154254832432432
# Stock name : cost, Price : 96.17006946409266
# Stock name : agen, Price : 2.999889955984556
# Stock name : ctg, Price : 9.576830107335908
# Stock name : csx, Price : 37.15074516833977
# Stock name : cnmd, Price : 31.917447902316603
# Stock name : dmlp, Price : 22.28328186100386
# Stock name : dspg, Price : 9.215841698069498
# Stock name : arci, Price : 3.1327799227799225
# Stock name : aray, Price : 7.887376223391812
# Stock name : brid, Price : 8.972416988030886
# Stock name : bsf, Price : 8.928162200386101
# Stock name : bstc, Price : 25.10273743629343
# Stock name : casi, Price : 1.617906349034749
# Stock name : flir, Price : 30.795725856370655
# Stock name : centa, Price : 10.959813017140632
# Stock name : fcap, Price : 20.154212339768343
# Stock name : crzo, Price : 34.66379924324325
# Stock name : cac, Price : 35.50384555559845
# Stock name : chco, Price : 39.56640153011583
# Stock name : atrs, Price : 2.035023166023166
# Stock name : drad, Price : 3.053988416988417
# Stock name : cdzi, Price : 10.901432437837839
# Stock name : cswc, Price : 77.7559074069498
# Stock name : esrx, Price : 67.4280848891892
# Stock name : arna, Price : 4.915745173745174
# Stock name : clwt, Price : 2.6171322247104247
# Stock name : ande, Price : 41.82902698030888
# Stock name : cobz, Price : 10.071579151737453
# Stock name : creg, Price : 1.6028996138996137
# Stock name : bldr, Price : 6.9454671849420855
# Stock name : feim, Price : 8.712000000000002
# Stock name : evbs, Price : 8.45465635868726
# Stock name : atsg, Price : 6.652401541698842
# Stock name : cwbc, Price : 5.892640926640927
# Stock name : amd, Price : 6.005552123166024
# Stock name : cmls, Price : 3.678938223938224
# Stock name : airm, Price : 46.91825888803089
# Stock name : dram, Price : 2.0592628378378377
# Stock name : esio, Price : 11.514586870656371
# Stock name : brkr, Price : 15.865401542471044
# Stock name : atlc, Price : 6.211756745173745
# Stock name : carv, Price : 6.87222652972973
# Stock name : avnw, Price : 5.723947867953668
# Stock name : crvl, Price : 37.4438649034749
# Stock name : aobc, Price : 10.59406178030888
# Stock name : abmd, Price : 33.22242086100386
# Stock name : amrb, Price : 10.411073202702703
# Stock name : becn, Price : 25.59151352046332
# Stock name : bsrr, Price : 16.1401776046332
# Stock name : acnb, Price : 17.3435289003861
# Stock name : fcco, Price : 10.53771429034749
# Stock name : abio, Price : 2.2518008
# Stock name : alks, Price : 28.143567575675675
# Stock name : adp, Price : 61.03234735559846
# Stock name : axti, Price : 3.8255212355212356
# Stock name : dwch, Price : 8.038034755212355
# Stock name : ctas, Price : 50.478884142471045
# Stock name : anat, Price : 97.93825093397682
# Stock name : bbh, Price : 113.28309655096525
# Stock name : aiq, Price : 10.171544398841698
# Stock name : colb, Price : 23.599138993050197
# Stock name : bbsi, Price : 30.425525077220083
# Stock name : banr, Price : 26.6042348019305
# Stock name : anss, Price : 62.32520078146718
# Stock name : dynt, Price : 1.822119691119691
# Stock name : eng, Price : 3.6441969108108103
# Stock name : flic, Price : 27.732250961776057

# %%
# Calculate the stock symbol with the minimum average closing price

stock, price = min(average_closing_prices.items(), key = lambda x : x[1])
print(f"The minimum average closing price is {round(price,3)}$ of {stock}")
# Out:
# The minimum average closing price is 0.812$ of blfs

# %%
# Calculate the stock symbol with the maximum average closing price

stock, price = max(average_closing_prices.items(), key = lambda x : x[1])
print(f"The maximum average closing price is {round(price,3)}$ of {stock}")
# Out:
# The maximum average closing price is 275.134$ of amzn

# %% [markdown]
# ## Organize the trades by date
#
# Now we will calculate a dictionary where the keys are the days and the values are lists of pairs (volumne, stock_symbol) of all trades that occured on that day.

# %%
import math 
from multiprocessing import Pool
import functools 

def make_chunks(data, num_chunks) : 
    chunk_size = math.ceil(len(data) / num_chunks)
    return [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

def map_reduce(data, num_processes, mapper, reducer) : 
    chunks = make_chunks(data, num_processes)
    with Pool(num_processes) as pool : 
        chunks_results = pool.map(mapper, chunks)
    return functools.reduce(reducer, chunks_results) 

def stock_mapper(stock_chunks) : 
    result = {}
    for stock in stock_chunks : 
        for index, row in stock_prices[stock].iterrows() : 
            day = row['date']
            volume = row['volume']
            pair = (volume, stock)
            if day not in result : 
                result[day] = []
            result[day].append(pair)
    return result 

def stock_reducer(dict1, dict2) : 
    for key, value in dict2.items() : 
        if key not in dict1 : 
            dict1[key] = dict2[key]
        else : 
            dict1[key] += dict2[key]
    return dict1

# %%
stock_names = list(stock_prices.keys())
num_processes = os.cpu_count() 

trades_by_day = map_reduce(stock_names, num_processes, stock_mapper, stock_reducer)

# %% [markdown]
# ## Find the most-traded stock each day
#
# Finding the most-traded stock can help to find trends in the broader market and see which companies are "hot" at which times.

# %%
most_traded_by_day = {} 

for day in trades_by_day : 
    most_traded_by_day[day] = sorted(trades_by_day[day], reverse = True)[0]

# %%
print(most_traded_by_day['2007-01-03'])
print(most_traded_by_day['2007-01-04'])
print(most_traded_by_day['2007-01-05'])
print(most_traded_by_day['2007-01-08'])
# Out:
# (309579900, 'aapl')
# (211815100, 'aapl')
# (208685400, 'aapl')
# (199276700, 'aapl')

# %% [markdown]
# ## Searching for High Volume Days
#
# In order to search for all transactions on days with unusually high volumne, below task is needed.
#
# - Compute total volumne of trading for each day
# - Sort and find the 10 highest volume days overall

# %%
total_volume_by_day = []

for day in trades_by_day : 
    total_volume = sum([volumne for volumne, _ in trades_by_day[day]])
    total_volume_by_day.append((total_volume, day))

total_volume_by_day = sorted(total_volume_by_day, reverse = True)
total_volume_by_day[:10]
# Out:
# [(1964583900, '2008-01-23'),
#  (1770266900, '2008-10-10'),
#  (1611272800, '2007-07-26'),
#  (1599183500, '2008-10-08'),
#  (1578877700, '2008-01-22'),
#  (1559032100, '2008-02-07'),
#  (1555072400, '2008-09-29'),
#  (1553880500, '2007-11-08'),
#  (1536176400, '2008-01-16'),
#  (1533363200, '2008-01-24')]

# %% [markdown]
# ## Finding Profitable Stocks
#
# Our goal is to find which stocks would have been the most profitable to buy.
#
# - Subtracting the initial close price (first row) from the final close price (last row), then computing a percentage relative to the initial price. This tells us how much our initial investment woulde have grown or reduced.
# - Sorting all of the percentages.
# - Finding the 10 stocks that grew the most in the time period.

# %%
profitable_stocks = [] 

for stock in stock_prices : 
    initial = stock_prices[stock].loc[0, 'close']
    final = stock_prices[stock].loc[len(stock_prices)-1, 'close']
    percentage = 100 * (final - initial) / initial 
    profitable_stocks.append((percentage, stock))
    
profitable_stocks = sorted(profitable_stocks, reverse = True)
profitable_stocks[:10]
# Out:
# [(2748.9998500524816, 'arcw'),
#  (1523.75, 'bvsn'),
#  (847.6195238095239, 'cbmx'),
#  (458.8235294117647, 'axgn'),
#  (387.8048780487805, 'bstc'),
#  (322.64470471442286, 'cldx'),
#  (174.2621015348288, 'calm'),
#  (144.73684210526318, 'fhco'),
#  (125.64102564102566, 'bwen'),
#  (95.36163147163397, 'cpla')]
